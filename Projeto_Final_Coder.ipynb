# %%
import pandas as pd
from datetime import datetime
from plyer import notification
import requests
import sqlite3
import json

# %%
conn = sqlite3.connect('coderhouse.db' )

# %% [markdown]
# Função responsável por salvar o DataFrame no Banco de dados local.

# %%
def salva_bd(df, nome_tabela):
    conn = sqlite3.connect('coderhouse.db')
    df.to_sql(nome_tabela,conn,if_exists='replace',index = False)
    conn.close()
    return None

# %% [markdown]
# Função responsável por carregar o DataFrame do banco de dados local.

# %%
def carrega_bd(nome_tabela):
    conn = sqlite3.connect('coderhouse.db')
    query = f"select * from {nome_tabela}"
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

# %% [markdown]
# Função responsável por listar todas as tabelas salvas no banco de dados local.

# %%
def lista_tabelas():
    conn = sqlite3.connect('coderhouse.db')
    query = "select name from sqlite_master where type='table'"
    schema = pd.read_sql(query, conn)
    conn.close()
    return schema

# %%
urls = [ 
    'https://brasilapi.com.br/api/banks/v1', #bancos ok
    'https://brasilapi.com.br/api/cvm/corretoras/v1', #corretoras ok
    'https://restcountries.com/v3.1/all' #rest countries ok
]

# %% [markdown]
# Função responsável por emitir um alerta caso a requisição da API retorne falha.

# %%
def Alerta(nivel, base, etapa):
    
    data_atual = datetime.now()
    data_formatada = data_atual.strftime('%d/%m/%d')
    mensagem = (f'Falha no carregamento da base {base} na etapa {etapa} em {data_formatada}')
    title = nivel
    notification.notify(title = title, message= mensagem, timeout= 10)

# %% [markdown]
# Função responsável por direcionar as APIs em seus respectivos Data Frames.

# %%
def Extraçao():

    global df_bancos, df_corretoras, df_resties

    for url in urls:
        request = requests.get(url)
        response_code = request.status_code
        if response_code == 200:
            if url == 'https://brasilapi.com.br/api/banks/v1':
                df_bancos = pd.DataFrame(request.json())
                
            elif url == 'https://brasilapi.com.br/api/cvm/corretoras/v1':
                df_corretoras = pd.DataFrame(request.json())
                
            elif url == 'https://restcountries.com/v3.1/all':
                df_resties = pd.DataFrame(request.json())
                
            else:
                print('URL fora da base de dados.')
        else:
            nivel = 'ATENÇÃO: Erro Grave'
            Alerta(nivel = nivel, base = 'APIs', etapa = 'Extraçao')

# %%
Extraçao()

# %% [markdown]
#                                            INICIANDO TRATAMENTO DO DF_BANCOS

# %%
df_bancos.head(2)
# Out:
#        ispb                        name  code                      fullName
# 0  00000000          BCO DO BRASIL S.A.   1.0          Banco do Brasil S.A.
# 1  00000208  BRB - BCO DE BRASILIA S.A.  70.0  BRB - BANCO DE BRASILIA S.A.

# %%
df_bancos_mod = df_bancos.copy() #mantendo o df original sem que o mesmo seja alterado pelas modificações posteriores

# %%
df_bancos_mod.head(2)
# Out:
#        ispb                        name  code                      fullName
# 0  00000000          BCO DO BRASIL S.A.   1.0          Banco do Brasil S.A.
# 1  00000208  BRB - BCO DE BRASILIA S.A.  70.0  BRB - BANCO DE BRASILIA S.A.

# %%
df_bancos_mod['code'].fillna(0, inplace=True)

# %%
df_bancos_mod['code'] = df_bancos_mod['code'].astype(int)

# %%
colunas_com_nan = ['name', 'fullName']

# %%
df_bancos_mod = df_bancos_mod.dropna(subset=colunas_com_nan)

# %%
df_bancos_mod['fullName'] = df_bancos_mod['fullName'].str.upper()

# %%
df_bancos_mod['name'] = df_bancos_mod['name'].str.upper()

# %%
df_bancos_mod.rename(columns={'ispb': 'ISPB'}, inplace=True)
df_bancos_mod.rename(columns={'name': 'SOCIAL'}, inplace=True)
df_bancos_mod.rename(columns={'code': 'CÓDIGO'}, inplace=True)
df_bancos_mod.rename(columns={'fullName': 'RAZÃO SOCIAL'}, inplace=True)

# %%
df_bancos_mod.head(4)
# Out:
#        ISPB                      SOCIAL  CÓDIGO  \
# 0  00000000          BCO DO BRASIL S.A.       1
# 1  00000208  BRB - BCO DE BRASILIA S.A.      70
# 2  00038121                       SELIC       0
# 3  00038166                       BACEN       0
#
#                       RAZÃO SOCIAL
# 0             BANCO DO BRASIL S.A.
# 1     BRB - BANCO DE BRASILIA S.A.
# 2  BANCO CENTRAL DO BRASIL - SELIC
# 3          BANCO CENTRAL DO BRASIL

# %% [markdown]
# SALVANDO E ENVIANDO O DF PARA O BANCO DE DADOS LOCAL

# %%
salva_bd(df_bancos_mod,'bancos')

# %%
lista_tabelas()
# Out:
#            name
# 0  restaurantes
# 1        bancos

# %%
bancos_teste = carrega_bd('bancos')

# %%
bancos_teste.head(2)
# Out:
#        ISPB                      SOCIAL  CÓDIGO                  RAZÃO SOCIAL
# 0  00000000          BCO DO BRASIL S.A.       1          BANCO DO BRASIL S.A.
# 1  00000208  BRB - BCO DE BRASILIA S.A.      70  BRB - BANCO DE BRASILIA S.A.

# %% [markdown]
#                                        INICIANDO TRATAMENTO DO DF_CORRETORAS

# %%
df_corretoras.head(2)
# Out:
#              cnpj        type  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
#
#                                          nome_social        nome_comercial  \
# 0                                      4UM DTVM S.A.     4UM INVESTIMENTOS
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...  ABC BRASIL CORRETORA
#
#       status                           email  telefone       cep    pais  uf  \
# 0  CANCELADA             controle@4um.com.br  33519966  80420210  BRASIL  PR
# 1  CANCELADA  regina.tkatch@abcbrasil.com.br  31702172   1453000          SP
#
#    municipio      bairro complemento                      logradouro  \
# 0   CURITIBA      CENTRO    4º ANDAR  R. VISCONDE DO RIO BRANCO 1488
# 1  SÃO PAULO  ITAIM BIBI    2º ANDAR          AV. CIDADE JARDIM, 803
#
#   data_patrimonio_liquido valor_patrimonio_liquido codigo_cvm  \
# 0              2005-12-31               4228660.18       2275
# 1              2002-12-31                     0.00       3514
#
#   data_inicio_situacao data_registro
# 0           2006-10-05    1968-01-15
# 1           2002-10-14    2002-10-14

# %%
df_corretoras_mod = df_corretoras.copy()

# %%
df_corretoras_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cnpj                      373 non-null    object
#  1   type                      373 non-null    object
#  2   nome_social               373 non-null    object
#  3   nome_comercial            373 non-null    object
#  4   status                    373 non-null    object
#  5   email                     373 non-null    object
#  6   telefone                  373 non-null    object
#  7   cep                       373 non-null    object
#  8   pais                      373 non-null    object
#  9   uf                        373 non-null    object
#  10  municipio                 373 non-null    object
#  11  bairro                    373 non-null    object
#  12  complemento               373 non-null    object
#  13  logradouro                373 non-null    object
#  14  data_patrimonio_liquido   373 non-null    object
#  15  valor_patrimonio_liquido  373 non-null    object
#  16  codigo_cvm                373 non-null    object
#  17  data_inicio_situacao      373 non-null    object
#  18  data_registro             373 non-null    object
# dtypes: object(19)
# memory usage: 55.5+ KB

# %%
df_corretoras_mod['data_patrimonio_liquido']
# Out:
# 0      2005-12-31
# 1      2002-12-31
# 2      1989-12-31
# 3      2022-12-31
# 4      2000-12-31
#           ...
# 368    2017-12-31
# 369    2017-12-31
# 370    2022-12-31
# 371    1996-12-31
# 372    2022-12-31
# Name: data_patrimonio_liquido, Length: 373, dtype: object

# %%
df_corretoras_mod['data_patrimonio_liquido'] = pd.to_datetime(df_corretoras_mod['data_patrimonio_liquido'])

# %%
df_corretoras_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cnpj                      373 non-null    object
#  1   type                      373 non-null    object
#  2   nome_social               373 non-null    object
#  3   nome_comercial            373 non-null    object
#  4   status                    373 non-null    object
#  5   email                     373 non-null    object
#  6   telefone                  373 non-null    object
#  7   cep                       373 non-null    object
#  8   pais                      373 non-null    object
#  9   uf                        373 non-null    object
#  10  municipio                 373 non-null    object
#  11  bairro                    373 non-null    object
#  12  complemento               373 non-null    object
#  13  logradouro                373 non-null    object
#  14  data_patrimonio_liquido   370 non-null    datetime64[ns]
#  15  valor_patrimonio_liquido  373 non-null    object
#  16  codigo_cvm                373 non-null    object
#  17  data_inicio_situacao      373 non-null    object
#  18  data_registro             373 non-null    object
# dtypes: datetime64[ns](1), object(18)
# memory usage: 55.5+ KB

# %%
df_corretoras_mod['data_patrimonio_liquido'] = df_corretoras_mod['data_patrimonio_liquido'].dt.strftime('%d/%m/%Y')

# %%
df_corretoras_mod['data_inicio_situacao']
# Out:
# 0      2006-10-05
# 1      2002-10-14
# 2      1990-06-12
# 3      2022-06-20
# 4      2001-04-11
#           ...
# 368    2018-08-27
# 369    2019-09-24
# 370    1967-12-06
# 371    1997-02-21
# 372    1998-02-10
# Name: data_inicio_situacao, Length: 373, dtype: object

# %%
df_corretoras_mod['data_inicio_situacao'] = pd.to_datetime(df_corretoras_mod['data_inicio_situacao'])

# %%
df_corretoras_mod['data_inicio_situacao'] = df_corretoras_mod['data_inicio_situacao'].dt.strftime('%d/%m/%Y')

# %%
df_corretoras_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cnpj                      373 non-null    object
#  1   type                      373 non-null    object
#  2   nome_social               373 non-null    object
#  3   nome_comercial            373 non-null    object
#  4   status                    373 non-null    object
#  5   email                     373 non-null    object
#  6   telefone                  373 non-null    object
#  7   cep                       373 non-null    object
#  8   pais                      373 non-null    object
#  9   uf                        373 non-null    object
#  10  municipio                 373 non-null    object
#  11  bairro                    373 non-null    object
#  12  complemento               373 non-null    object
#  13  logradouro                373 non-null    object
#  14  data_patrimonio_liquido   370 non-null    object
#  15  valor_patrimonio_liquido  373 non-null    object
#  16  codigo_cvm                373 non-null    object
#  17  data_inicio_situacao      373 non-null    object
#  18  data_registro             373 non-null    object
# dtypes: object(19)
# memory usage: 55.5+ KB

# %%
df_corretoras_mod['data_registro'] = pd.to_datetime(df_corretoras_mod['data_registro'])

# %%
df_corretoras_mod['data_registro'] = df_corretoras_mod['data_registro'].dt.strftime('%d/%m/%Y')

# %%
df_corretoras_mod.head(2)
# Out:
#              cnpj        type  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
#
#                                          nome_social        nome_comercial  \
# 0                                      4UM DTVM S.A.     4UM INVESTIMENTOS
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...  ABC BRASIL CORRETORA
#
#       status                           email  telefone       cep    pais  uf  \
# 0  CANCELADA             controle@4um.com.br  33519966  80420210  BRASIL  PR
# 1  CANCELADA  regina.tkatch@abcbrasil.com.br  31702172   1453000          SP
#
#    municipio      bairro complemento                      logradouro  \
# 0   CURITIBA      CENTRO    4º ANDAR  R. VISCONDE DO RIO BRANCO 1488
# 1  SÃO PAULO  ITAIM BIBI    2º ANDAR          AV. CIDADE JARDIM, 803
#
#   data_patrimonio_liquido valor_patrimonio_liquido codigo_cvm  \
# 0              31/12/2005               4228660.18       2275
# 1              31/12/2002                     0.00       3514
#
#   data_inicio_situacao data_registro
# 0           05/10/2006    15/01/1968
# 1           14/10/2002    14/10/2002

# %%
df_corretoras_mod.columns = [col.capitalize() for col in df_corretoras.columns]

# %%
df_corretoras_mod.rename(columns={'Cnpj': 'CNPJ'}, inplace=True)

# %%
df_corretoras_mod.rename(columns={'Uf': 'UF'}, inplace=True)

# %%
df_corretoras_mod.rename(columns={'Cep': 'CEP'}, inplace=True)

# %%
df_corretoras_mod.rename(columns={'Email': 'E-mail'}, inplace=True)

# %%
df_corretoras_mod.rename(columns={'Pais': 'País'}, inplace=True)

# %%
df_corretoras_mod.rename(columns={'Type': 'Tipo'}, inplace=True)

# %%
df_corretoras_mod.head(2)
# Out:
#              CNPJ        Tipo  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
#
#                                          Nome_social        Nome_comercial  \
# 0                                      4UM DTVM S.A.     4UM INVESTIMENTOS
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...  ABC BRASIL CORRETORA
#
#       Status                          E-mail  Telefone       CEP    País  UF  \
# 0  CANCELADA             controle@4um.com.br  33519966  80420210  BRASIL  PR
# 1  CANCELADA  regina.tkatch@abcbrasil.com.br  31702172   1453000          SP
#
#    Municipio      Bairro Complemento                      Logradouro  \
# 0   CURITIBA      CENTRO    4º ANDAR  R. VISCONDE DO RIO BRANCO 1488
# 1  SÃO PAULO  ITAIM BIBI    2º ANDAR          AV. CIDADE JARDIM, 803
#
#   Data_patrimonio_liquido Valor_patrimonio_liquido Codigo_cvm  \
# 0              31/12/2005               4228660.18       2275
# 1              31/12/2002                     0.00       3514
#
#   Data_inicio_situacao Data_registro
# 0           05/10/2006    15/01/1968
# 1           14/10/2002    14/10/2002

# %%
df_corretoras_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CNPJ                      373 non-null    object
#  1   Tipo                      373 non-null    object
#  2   Nome_social               373 non-null    object
#  3   Nome_comercial            373 non-null    object
#  4   Status                    373 non-null    object
#  5   E-mail                    373 non-null    object
#  6   Telefone                  373 non-null    object
#  7   CEP                       373 non-null    object
#  8   País                      373 non-null    object
#  9   UF                        373 non-null    object
#  10  Municipio                 373 non-null    object
#  11  Bairro                    373 non-null    object
#  12  Complemento               373 non-null    object
#  13  Logradouro                373 non-null    object
#  14  Data_patrimonio_liquido   370 non-null    object
#  15  Valor_patrimonio_liquido  373 non-null    object
#  16  Codigo_cvm                373 non-null    object
#  17  Data_inicio_situacao      373 non-null    object
#  18  Data_registro             373 non-null    object
# dtypes: object(19)
# memory usage: 55.5+ KB

# %%
linhas_com_missing = df_corretoras_mod[df_corretoras_mod.isna().any(axis=1)]

# %%
linhas_com_missing
# Out:
#                CNPJ        Tipo  \
# 18   99988065000154  CORRETORAS
# 70   12865507000197  CORRETORAS
# 229  36864992000142  CORRETORAS
#
#                                            Nome_social Nome_comercial  \
# 18                              ALVES FERREIRA CV LTDA
# 70   BRICKELL S.A. CRÉDITO, FINANCIAMENTO E INVESTI...             --
# 229  MAF DISTRIBUIDORA DE TITULOS E VALORES MOBILIA...       MAF DTVM
#
#         Status                                E-mail  Telefone       CEP  \
# 18   CANCELADA                                                     80020
# 70   CANCELADA        brickellcfi@brickellcfi.com.br  21989735   4534002
# 229  CANCELADA  juridico.admfiduciaria@apexgroup.com  45601000  22250040
#
#        País  UF       Municipio      Bairro          Complemento  \
# 18   BRASIL  PR        CURITIBA
# 70   BRASIL  SP       SÃO PAULO  ITAIM BIBI      SALA 1302 E1303
# 229          RJ  RIO DE JANEIRO    BOTAFOGO  TORRE PÃO DE AÇUCAR
#
#                                  Logradouro Data_patrimonio_liquido  \
# 18           RUA MAL.DEODORO, 235 - 2 ANDAR                     NaN
# 70                  R JOAQUIM FLORIANO, 466                     NaN
# 229  PRAIA DE BOTAFOGO, 501/ 5º ANDAR PARTE                     NaN
#
#     Valor_patrimonio_liquido Codigo_cvm Data_inicio_situacao Data_registro
# 18                                 2747           29/04/1993    27/12/1991
# 70                                 3492           23/01/1995    28/03/1988
# 229                                3751           06/11/2020    06/11/2020

# %%
df_corretoras_mod = df_corretoras_mod.dropna()

# %%
df_corretoras_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 0 to 372
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CNPJ                      370 non-null    object
#  1   Tipo                      370 non-null    object
#  2   Nome_social               370 non-null    object
#  3   Nome_comercial            370 non-null    object
#  4   Status                    370 non-null    object
#  5   E-mail                    370 non-null    object
#  6   Telefone                  370 non-null    object
#  7   CEP                       370 non-null    object
#  8   País                      370 non-null    object
#  9   UF                        370 non-null    object
#  10  Municipio                 370 non-null    object
#  11  Bairro                    370 non-null    object
#  12  Complemento               370 non-null    object
#  13  Logradouro                370 non-null    object
#  14  Data_patrimonio_liquido   370 non-null    object
#  15  Valor_patrimonio_liquido  370 non-null    object
#  16  Codigo_cvm                370 non-null    object
#  17  Data_inicio_situacao      370 non-null    object
#  18  Data_registro             370 non-null    object
# dtypes: object(19)
# memory usage: 57.8+ KB

# %%
df_corretoras_mod.head(5)
# Out:
#              CNPJ        Tipo  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
# 2  10664027000132  CORRETORAS
# 3  44527444000155  CORRETORAS
# 4  33819590000138  CORRETORAS
#
#                                          Nome_social        Nome_comercial  \
# 0                                      4UM DTVM S.A.     4UM INVESTIMENTOS
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...  ABC BRASIL CORRETORA
# 2                                 ABERTURA CCVM LTDA    ABERTURA CCVM LTDA
# 3  ABN AMRO CORRETORA DE T-TULOS E VALORES MOBILI...
# 4            AÇÃO S.A. CORRETORA DE VALORES E CÂMBIO           ACAO SA CVC
#
#                     Status                            E-mail  Telefone  \
# 0                CANCELADA               controle@4um.com.br  33519966
# 1                CANCELADA    regina.tkatch@abcbrasil.com.br  31702172
# 2                CANCELADA
# 3  EM FUNCIONAMENTO NORMAL  canal.comunicacao@br.abnamro.com  30737417
# 4                CANCELADA                                     5095755
#
#         CEP    País  UF       Municipio        Bairro         Complemento  \
# 0  80420210  BRASIL  PR        CURITIBA        CENTRO            4º ANDAR
# 1   1453000          SP       SÃO PAULO    ITAIM BIBI            2º ANDAR
# 2  50010240  BRASIL  PE          RECIFE
# 3   4551010          SP       SÃO PAULO  VILA OLIMPIA  11¦ ANDAR, CJ. 111
# 4  20040040  BRASIL  RJ  RIO DE JANEIRO        CENTRO
#
#                             Logradouro Data_patrimonio_liquido  \
# 0       R. VISCONDE DO RIO BRANCO 1488              31/12/2005
# 1               AV. CIDADE JARDIM, 803              31/12/2002
# 2       R DO IMP.D.PEDRO II 239/CJ.102              31/12/1989
# 3  RUA FIDÛNCIO RAMOS, N¦ 302, TORRE B              31/12/2022
# 4       PRAÇA OLAVO BILAC, 28/ SL. 608              31/12/2000
#
#   Valor_patrimonio_liquido Codigo_cvm Data_inicio_situacao Data_registro
# 0               4228660.18       2275           05/10/2006    15/01/1968
# 1                     0.00       3514           14/10/2002    14/10/2002
# 2               5995252.29        329           12/06/1990    08/07/1986
# 3               3729687.41       3794           20/06/2022    20/06/2022
# 4                291862.38       1112           11/04/2001    19/04/1968

# %% [markdown]
# SALVANDO E ENVIANDO O DF PARA O BANCO DE DADOS LOCAL

# %%
salva_bd(df_corretoras_mod,'corretoras')

# %%
lista_tabelas()
# Out:
#            name
# 0  restaurantes
# 1        bancos
# 2    corretoras

# %%
corretora_teste = carrega_bd('corretoras')

# %%
corretora_teste.head(2)
# Out:
#              CNPJ        Tipo  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
#
#                                          Nome_social        Nome_comercial  \
# 0                                      4UM DTVM S.A.     4UM INVESTIMENTOS
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...  ABC BRASIL CORRETORA
#
#       Status                          E-mail  Telefone       CEP    País  UF  \
# 0  CANCELADA             controle@4um.com.br  33519966  80420210  BRASIL  PR
# 1  CANCELADA  regina.tkatch@abcbrasil.com.br  31702172   1453000          SP
#
#    Municipio      Bairro Complemento                      Logradouro  \
# 0   CURITIBA      CENTRO    4º ANDAR  R. VISCONDE DO RIO BRANCO 1488
# 1  SÃO PAULO  ITAIM BIBI    2º ANDAR          AV. CIDADE JARDIM, 803
#
#   Data_patrimonio_liquido Valor_patrimonio_liquido Codigo_cvm  \
# 0              31/12/2005               4228660.18       2275
# 1              31/12/2002                     0.00       3514
#
#   Data_inicio_situacao Data_registro
# 0           05/10/2006    15/01/1968
# 1           14/10/2002    14/10/2002

# %% [markdown]
#                                          INICIANDO TRATAMENTO DO DF_RESTIES

# %%
df_resties.head(2)
# Out:
#                                                 name         tld cca2 ccn3  \
# 0  {'common': 'French Polynesia', 'official': 'Fr...       [.pf]   PF  258
# 1  {'common': 'Saint Martin', 'official': 'Saint ...  [.fr, .gp]   MF  663
#
#   cca3 independent               status  unMember  \
# 0  PYF       False  officially-assigned     False
# 1  MAF       False  officially-assigned     False
#
#                                       currencies  \
# 0  {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1       {'EUR': {'name': 'Euro', 'symbol': '€'}}
#
#                                   idd  ...       continents  \
# 0  {'root': '+6', 'suffixes': ['89']}  ...        [Oceania]
# 1  {'root': '+5', 'suffixes': ['90']}  ...  [North America]
#
#                                                flags  \
# 0  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
# 1  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
#
#                                           coatOfArms startOfWeek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
# 1                                                 {}      monday
#
#                      capitalInfo  \
# 0  {'latlng': [-17.53, -149.56]}
# 1    {'latlng': [18.07, -63.08]}
#
#                                           postalCode borders  cioc  gini fifa
# 0  {'format': '#####', 'regex': '^((97|98)7\d{2})$'}     NaN   NaN   NaN  NaN
# 1                              {'format': '### ###'}   [SXM]   NaN   NaN  NaN
#
# [2 rows x 35 columns]

# %%
df_resties_mod = df_resties.copy()

# %%
df_resties_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          250 non-null    object
#  1   tld           249 non-null    object
#  2   cca2          250 non-null    object
#  3   ccn3          249 non-null    object
#  4   cca3          250 non-null    object
#  5   independent   249 non-null    object
#  6   status        250 non-null    object
#  7   unMember      250 non-null    bool
#  8   currencies    247 non-null    object
#  9   idd           250 non-null    object
#  10  capital       246 non-null    object
#  11  altSpellings  250 non-null    object
#  12  region        250 non-null    object
#  13  subregion     245 non-null    object
#  14  languages     249 non-null    object
#  15  translations  250 non-null    object
#  16  latlng        250 non-null    object
#  17  landlocked    250 non-null    bool
#  18  area          250 non-null    float64
#  19  demonyms      249 non-null    object
#  20  flag          250 non-null    object
#  21  maps          250 non-null    object
#  22  population    250 non-null    int64
#  23  car           250 non-null    object
#  24  timezones     250 non-null    object
#  25  continents    250 non-null    object
#  26  flags         250 non-null    object
#  27  coatOfArms    250 non-null    object
#  28  startOfWeek   250 non-null    object
#  29  capitalInfo   250 non-null    object
#  30  postalCode    149 non-null    object
#  31  borders       165 non-null    object
#  32  cioc          206 non-null    object
#  33  gini          167 non-null    object
#  34  fifa          206 non-null    object
# dtypes: bool(2), float64(1), int64(1), object(31)
# memory usage: 65.1+ KB

# %%
valores_ausentes_por_coluna = df_resties_mod.isna().sum()

# %%
print(valores_ausentes_por_coluna)
# Out:
# name              0
# tld               1
# cca2              0
# ccn3              1
# cca3              0
# independent       1
# status            0
# unMember          0
# currencies        3
# idd               0
# capital           4
# altSpellings      0
# region            0
# subregion         5
# languages         1
# translations      0
# latlng            0
# landlocked        0
# area              0
# demonyms          1
# flag              0
# maps              0
# population        0
# car               0
# timezones         0
# continents        0
# flags             0
# coatOfArms        0
# startOfWeek       0
# capitalInfo       0
# postalCode      101
# borders          85
# cioc             44
# gini             83
# fifa             44
# dtype: int64

# %%
df_resties_mod.columns = [col.capitalize() for col in df_resties_mod.columns]

# %%
df_resties_mod.head(2)
# Out:
#                                                 Name         Tld Cca2 Ccn3  \
# 0  {'common': 'French Polynesia', 'official': 'Fr...       [.pf]   PF  258
# 1  {'common': 'Saint Martin', 'official': 'Saint ...  [.fr, .gp]   MF  663
#
#   Cca3 Independent               Status  Unmember  \
# 0  PYF       False  officially-assigned     False
# 1  MAF       False  officially-assigned     False
#
#                                       Currencies  \
# 0  {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1       {'EUR': {'name': 'Euro', 'symbol': '€'}}
#
#                                   Idd  ...       Continents  \
# 0  {'root': '+6', 'suffixes': ['89']}  ...        [Oceania]
# 1  {'root': '+5', 'suffixes': ['90']}  ...  [North America]
#
#                                                Flags  \
# 0  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
# 1  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
# 1                                                 {}      monday
#
#                      Capitalinfo  \
# 0  {'latlng': [-17.53, -149.56]}
# 1    {'latlng': [18.07, -63.08]}
#
#                                           Postalcode Borders  Cioc  Gini Fifa
# 0  {'format': '#####', 'regex': '^((97|98)7\d{2})$'}     NaN   NaN   NaN  NaN
# 1                              {'format': '### ###'}   [SXM]   NaN   NaN  NaN
#
# [2 rows x 35 columns]

# %%
df_resties_mod['Name'] = [pais['common']for pais in df_resties_mod['Name']]

# %%
df_resties_mod['Postalcode']
# Out:
# 0      {'format': '#####', 'regex': '^((97|98)7\d{2})$'}
# 1                                  {'format': '### ###'}
# 2               {'format': '####', 'regex': '^(\d{4})$'}
# 3      {'format': '#####', 'regex': '^((97|98)(4|7|8)...
# 4      {'format': 'CP ####', 'regex': '^(?:CP)*(\d{4}...
#                              ...
# 245                                                  NaN
# 246                                                  NaN
# 247                                                  NaN
# 248                                                  NaN
# 249    {'format': '@####@', 'regex': '^([a-zA-Z]\d{4}...
# Name: Postalcode, Length: 250, dtype: object

# %%
df_resties_mod = df_resties_mod.drop('Postalcode', axis=1)

# %%
pd.options.display.max_columns = None

# %%
df_resties_mod.head(2)
# Out:
#                Name         Tld Cca2 Ccn3 Cca3 Independent  \
# 0  French Polynesia       [.pf]   PF  258  PYF       False
# 1      Saint Martin  [.fr, .gp]   MF  663  MAF       False
#
#                 Status  Unmember  \
# 0  officially-assigned     False
# 1  officially-assigned     False
#
#                                       Currencies  \
# 0  {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1       {'EUR': {'name': 'Euro', 'symbol': '€'}}
#
#                                   Idd    Capital  \
# 0  {'root': '+6', 'suffixes': ['89']}  [Papeetē]
# 1  {'root': '+5', 'suffixes': ['90']}  [Marigot]
#
#                                         Altspellings    Region  Subregion  \
# 0  [PF, Polynésie française, French Polynesia, Pō...   Oceania  Polynesia
# 1  [MF, Collectivity of Saint Martin, Collectivit...  Americas  Caribbean
#
#            Languages                                       Translations  \
# 0  {'fra': 'French'}  {'ara': {'official': 'بولينزيا الفرنسية', 'com...
# 1  {'fra': 'French'}  {'ara': {'official': 'سانت مارتن', 'common': '...
#
#                 Latlng  Landlocked    Area  \
# 0  [17.6797, 149.4068]       False  4167.0
# 1   [18.0708, 63.0501]       False    53.0
#
#                                             Demonyms Flag  \
# 0  {'eng': {'f': 'French Polynesian', 'm': 'Frenc...   🇵🇫
# 1  {'eng': {'f': 'Saint Martin Islander', 'm': 'S...   🇲🇫
#
#                                                 Maps  Population  \
# 0  {'googleMaps': 'https://goo.gl/maps/xgg6BQTRye...      280904
# 1  {'googleMaps': 'https://goo.gl/maps/P9ho9QuJ9E...       38659
#
#                                  Car                          Timezones  \
# 0  {'signs': ['F'], 'side': 'right'}  [UTC-10:00, UTC-09:30, UTC-09:00]
# 1  {'signs': ['F'], 'side': 'right'}                        [UTC-04:00]
#
#         Continents                                              Flags  \
# 0        [Oceania]  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
# 1  [North America]  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
# 1                                                 {}      monday
#
#                      Capitalinfo Borders Cioc Gini Fifa
# 0  {'latlng': [-17.53, -149.56]}     NaN  NaN  NaN  NaN
# 1    {'latlng': [18.07, -63.08]}   [SXM]  NaN  NaN  NaN

# %%
df_resties_mod['Currencies']
# Out:
# 0          {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1               {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 2      {'VES': {'name': 'Venezuelan bolívar soberano'...
# 3               {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 4      {'USD': {'name': 'United States dollar', 'symb...
#                              ...
# 245    {'USD': {'name': 'United States dollar', 'symb...
# 246    {'BWP': {'name': 'Botswana pula', 'symbol': 'P'}}
# 247    {'PAB': {'name': 'Panamanian balboa', 'symbol'...
# 248    {'XAF': {'name': 'Central African CFA franc', ...
# 249    {'USD': {'name': 'United States dollar', 'symb...
# Name: Currencies, Length: 250, dtype: object

# %%
df_resties_mod.head(1)
# Out:
#                Name    Tld Cca2 Ccn3 Cca3 Independent               Status  \
# 0  French Polynesia  [.pf]   PF  258  PYF       False  officially-assigned
#
#    Unmember                                     Currencies  \
# 0     False  {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
#
#                                   Idd    Capital  \
# 0  {'root': '+6', 'suffixes': ['89']}  [Papeetē]
#
#                                         Altspellings   Region  Subregion  \
# 0  [PF, Polynésie française, French Polynesia, Pō...  Oceania  Polynesia
#
#            Languages                                       Translations  \
# 0  {'fra': 'French'}  {'ara': {'official': 'بولينزيا الفرنسية', 'com...
#
#                 Latlng  Landlocked    Area  \
# 0  [17.6797, 149.4068]       False  4167.0
#
#                                             Demonyms Flag  \
# 0  {'eng': {'f': 'French Polynesian', 'm': 'Frenc...   🇵🇫
#
#                                                 Maps  Population  \
# 0  {'googleMaps': 'https://goo.gl/maps/xgg6BQTRye...      280904
#
#                                  Car                          Timezones  \
# 0  {'signs': ['F'], 'side': 'right'}  [UTC-10:00, UTC-09:30, UTC-09:00]
#
#   Continents                                              Flags  \
# 0  [Oceania]  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                      Capitalinfo Borders Cioc Gini Fifa
# 0  {'latlng': [-17.53, -149.56]}     NaN  NaN  NaN  NaN

# %%
df_resties_mod['Currencies'].dropna()
# Out:
# 0          {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1               {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 2      {'VES': {'name': 'Venezuelan bolívar soberano'...
# 3               {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 4      {'USD': {'name': 'United States dollar', 'symb...
#                              ...
# 245    {'USD': {'name': 'United States dollar', 'symb...
# 246    {'BWP': {'name': 'Botswana pula', 'symbol': 'P'}}
# 247    {'PAB': {'name': 'Panamanian balboa', 'symbol'...
# 248    {'XAF': {'name': 'Central African CFA franc', ...
# 249    {'USD': {'name': 'United States dollar', 'symb...
# Name: Currencies, Length: 247, dtype: object

# %%
# Função para extrair a chave 'name' do dicionário
def extrair_nome_moeda(dicionario):
    if isinstance(dicionario, dict):
        for chave, valor in dicionario.items():
            if 'name' in valor:
                return valor['name']
    return None
        

# Extrair e atribuir a chave 'name' à coluna 'currencies'
df_resties_mod['Currencies'] = df_resties_mod['Currencies'].apply(extrair_nome_moeda)

# Renomear a coluna para 'Currencies_Name'
df_resties_mod = df_resties_mod.rename(columns={'Currencies': 'Currencies_Name'})

# %%
df_resties_mod.head(1)
# Out:
#                Name    Tld Cca2 Ccn3 Cca3 Independent               Status  \
# 0  French Polynesia  [.pf]   PF  258  PYF       False  officially-assigned
#
#    Unmember Currencies_Name                                 Idd    Capital  \
# 0     False       CFP franc  {'root': '+6', 'suffixes': ['89']}  [Papeetē]
#
#                                         Altspellings   Region  Subregion  \
# 0  [PF, Polynésie française, French Polynesia, Pō...  Oceania  Polynesia
#
#            Languages                                       Translations  \
# 0  {'fra': 'French'}  {'ara': {'official': 'بولينزيا الفرنسية', 'com...
#
#                 Latlng  Landlocked    Area  \
# 0  [17.6797, 149.4068]       False  4167.0
#
#                                             Demonyms Flag  \
# 0  {'eng': {'f': 'French Polynesian', 'm': 'Frenc...   🇵🇫
#
#                                                 Maps  Population  \
# 0  {'googleMaps': 'https://goo.gl/maps/xgg6BQTRye...      280904
#
#                                  Car                          Timezones  \
# 0  {'signs': ['F'], 'side': 'right'}  [UTC-10:00, UTC-09:30, UTC-09:00]
#
#   Continents                                              Flags  \
# 0  [Oceania]  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                      Capitalinfo Borders Cioc Gini Fifa
# 0  {'latlng': [-17.53, -149.56]}     NaN  NaN  NaN  NaN

# %%
df_resties_mod['Borders'].fillna('NA', inplace=True)

# %%
colunas_com_listas = df_resties_mod.columns[df_resties_mod.applymap(type).eq(list).any()]
# Out:
# C:\Users\junio\AppData\Local\Temp\ipykernel_13936\2574065366.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   colunas_com_listas = df_resties_mod.columns[df_resties_mod.applymap(type).eq(list).any()]

# %%
colunas_com_listas
# Out:
# Index(['Tld', 'Capital', 'Altspellings', 'Latlng', 'Timezones', 'Continents',
#        'Borders'],
#       dtype='object')

# %%
for colunas in colunas_com_listas:
    df_resties_mod[colunas] = df_resties_mod[colunas].apply(json.dumps)

# %%
df_resties_mod['Continents'] = df_resties_mod['Continents'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[2:-2])

# %%
df_resties_mod['Capital'] = df_resties_mod['Capital'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[2:-2])

# %%
df_resties_mod['Latlng'] = df_resties_mod['Latlng'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[1:-1])

# %%
df_resties_mod['Borders'] = df_resties_mod['Borders'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[1:-1])

# %%
df_resties_mod['Timezones'] = df_resties_mod['Timezones'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[1:-1])

# %%
df_resties_mod['Capital'] = df_resties_mod['Capital'].str.strip('"')

# %%
df_resties_mod = df_resties_mod.drop(columns=['Translations','Demonyms','Languages','Gini','Capitalinfo','Idd','Car','Tld','Altspellings','Maps','Flags','Coatofarms'])

# %%
def converter_dict_para_list(value):
    if isinstance(value, dict):
        return list(value)  # Converte o dicionário em uma string
    else:
        return value  # Mantém outros valores inalterados

# %%
df_resties_mod['Timezones'] = df_resties_mod['Timezones'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x[1:-1])

# %%
df_resties_mod.head(2)
# Out:
#                Name             Tld Cca2 Ccn3 Cca3 Independent  \
# 0  French Polynesia         [".pf"]   PF  258  PYF       False
# 1      Saint Martin  [".fr", ".gp"]   MF  663  MAF       False
#
#                 Status  Unmember Currencies_Name  \
# 0  officially-assigned     False       CFP franc
# 1  officially-assigned     False            Euro
#
#                                   Idd       Capital  \
# 0  {'root': '+6', 'suffixes': ['89']}  Papeet\u0113
# 1  {'root': '+5', 'suffixes': ['90']}       Marigot
#
#                                         Altspellings    Region  Subregion  \
# 0  ["PF", "Polyn\u00e9sie fran\u00e7aise", "Frenc...   Oceania  Polynesia
# 1  ["MF", "Collectivity of Saint Martin", "Collec...  Americas  Caribbean
#
#            Languages                                       Translations  \
# 0  {'fra': 'French'}  {'ara': {'official': 'بولينزيا الفرنسية', 'com...
# 1  {'fra': 'French'}  {'ara': {'official': 'سانت مارتن', 'common': '...
#
#               Latlng  Landlocked    Area  \
# 0  17.6797, 149.4068       False  4167.0
# 1   18.0708, 63.0501       False    53.0
#
#                                             Demonyms Flag  \
# 0  {'eng': {'f': 'French Polynesian', 'm': 'Frenc...   🇵🇫
# 1  {'eng': {'f': 'Saint Martin Islander', 'm': 'S...   🇲🇫
#
#                                                 Maps  Population  \
# 0  {'googleMaps': 'https://goo.gl/maps/xgg6BQTRye...      280904
# 1  {'googleMaps': 'https://goo.gl/maps/P9ho9QuJ9E...       38659
#
#                                  Car                            Timezones  \
# 0  {'signs': ['F'], 'side': 'right'}  UTC-10:00", "UTC-09:30", "UTC-09:00
# 1  {'signs': ['F'], 'side': 'right'}                            UTC-04:00
#
#       Continents                                              Flags  \
# 0        Oceania  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
# 1  North America  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
# 1                                                 {}      monday
#
#                      Capitalinfo Borders Cioc Gini Fifa
# 0  {'latlng': [-17.53, -149.56]}      NA  NaN  NaN  NaN
# 1    {'latlng': [18.07, -63.08]}   "SXM"  NaN  NaN  NaN

# %%
df_resties_mod['Cioc'] = df_resties_mod['Cioc'].fillna('Not_Apply')

# %%
valores_ausentes_por_coluna = df_resties_mod.isna().sum()

# %%
valores_ausentes_por_coluna
# Out:
# Name                0
# Tld                 0
# Cca2                0
# Ccn3                1
# Cca3                0
# Independent         1
# Status              0
# Unmember            0
# Currencies_Name     3
# Idd                 0
# Capital             0
# Altspellings        0
# Region              0
# Subregion           5
# Languages           1
# Translations        0
# Latlng              0
# Landlocked          0
# Area                0
# Demonyms            1
# Flag                0
# Maps                0
# Population          0
# Car                 0
# Timezones           0
# Continents          0
# Flags               0
# Coatofarms          0
# Startofweek         0
# Capitalinfo         0
# Borders             0
# Cioc                0
# Gini               83
# Fifa               44
# dtype: int64

# %%
df_resties_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             250 non-null    object
#  1   Tld              250 non-null    object
#  2   Cca2             250 non-null    object
#  3   Ccn3             249 non-null    object
#  4   Cca3             250 non-null    object
#  5   Independent      249 non-null    object
#  6   Status           250 non-null    object
#  7   Unmember         250 non-null    bool
#  8   Currencies_Name  247 non-null    object
#  9   Idd              250 non-null    object
#  10  Capital          250 non-null    object
#  11  Altspellings     250 non-null    object
#  12  Region           250 non-null    object
#  13  Subregion        245 non-null    object
#  14  Languages        249 non-null    object
#  15  Translations     250 non-null    object
#  16  Latlng           250 non-null    object
#  17  Landlocked       250 non-null    bool
#  18  Area             250 non-null    float64
#  19  Demonyms         249 non-null    object
#  20  Flag             250 non-null    object
#  21  Maps             250 non-null    object
#  22  Population       250 non-null    int64
#  23  Car              250 non-null    object
#  24  Timezones        250 non-null    object
#  25  Continents       250 non-null    object
#  26  Flags            250 non-null    object
#  27  Coatofarms       250 non-null    object
#  28  Startofweek      250 non-null    object
#  29  Capitalinfo      250 non-null    object
#  30  Borders          250 non-null    object
#  31  Cioc             250 non-null    object
#  32  Gini             167 non-null    object
#  33  Fifa             206 non-null    object
# dtypes: bool(2), float64(1), int64(1), object(30)
# memory usage: 63.1+ KB

# %%
mapeamento = {True: 'Yes', False: 'No'}

# %%
colunas_a_tratar = ['Independent', 'Unmember']
df_resties_mod[colunas_a_tratar] = df_resties_mod[colunas_a_tratar].replace(mapeamento)

# %%
df_resties_mod.head(2)
# Out:
#                Name             Tld Cca2 Ccn3 Cca3 Independent  \
# 0  French Polynesia         [".pf"]   PF  258  PYF          No
# 1      Saint Martin  [".fr", ".gp"]   MF  663  MAF          No
#
#                 Status Unmember Currencies_Name  \
# 0  officially-assigned       No       CFP franc
# 1  officially-assigned       No            Euro
#
#                                   Idd       Capital  \
# 0  {'root': '+6', 'suffixes': ['89']}  Papeet\u0113
# 1  {'root': '+5', 'suffixes': ['90']}       Marigot
#
#                                         Altspellings    Region  Subregion  \
# 0  ["PF", "Polyn\u00e9sie fran\u00e7aise", "Frenc...   Oceania  Polynesia
# 1  ["MF", "Collectivity of Saint Martin", "Collec...  Americas  Caribbean
#
#            Languages                                       Translations  \
# 0  {'fra': 'French'}  {'ara': {'official': 'بولينزيا الفرنسية', 'com...
# 1  {'fra': 'French'}  {'ara': {'official': 'سانت مارتن', 'common': '...
#
#               Latlng  Landlocked    Area  \
# 0  17.6797, 149.4068       False  4167.0
# 1   18.0708, 63.0501       False    53.0
#
#                                             Demonyms Flag  \
# 0  {'eng': {'f': 'French Polynesian', 'm': 'Frenc...   🇵🇫
# 1  {'eng': {'f': 'Saint Martin Islander', 'm': 'S...   🇲🇫
#
#                                                 Maps  Population  \
# 0  {'googleMaps': 'https://goo.gl/maps/xgg6BQTRye...      280904
# 1  {'googleMaps': 'https://goo.gl/maps/P9ho9QuJ9E...       38659
#
#                                  Car                            Timezones  \
# 0  {'signs': ['F'], 'side': 'right'}  UTC-10:00", "UTC-09:30", "UTC-09:00
# 1  {'signs': ['F'], 'side': 'right'}                            UTC-04:00
#
#       Continents                                              Flags  \
# 0        Oceania  {'png': 'https://flagcdn.com/w320/pf.png', 'sv...
# 1  North America  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
#
#                                           Coatofarms Startofweek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
# 1                                                 {}      monday
#
#                      Capitalinfo Borders       Cioc Gini Fifa
# 0  {'latlng': [-17.53, -149.56]}      NA  Not_Apply  NaN  NaN
# 1    {'latlng': [18.07, -63.08]}   "SXM"  Not_Apply  NaN  NaN

# %% [markdown]
# SALVANDO E ENVIANDO O DF PARA O BANCO DE DADOS LOCAL

# %%
salva_bd(df_resties_mod,'resties')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\junio\OneDrive\Documentos\curso_de_python_coderhouse\Jupyter\Projeto_Final_Coder.ipynb Cell 106 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=0'>1</a> salva_bd(df_resties_mod,'resties')
#
# c:\Users\junio\OneDrive\Documentos\curso_de_python_coderhouse\Jupyter\Projeto_Final_Coder.ipynb Cell 106 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=0'>1</a> def salva_bd(df, nome_tabela):
#       <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=1'>2</a>     conn = sqlite3.connect('coderhouse.db')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=2'>3</a>     df.to_sql(nome_tabela,conn,if_exists='replace',index = False)
#       <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=3'>4</a>     conn.close()
#       <a href='vscode-notebook-cell:/c%3A/Users/junio/OneDrive/Documentos/curso_de_python_coderhouse/Jupyter/Projeto_Final_Coder.ipynb#Y210sZmlsZQ%3D%3D?line=4'>5</a>     return None
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2443, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2433 table = SQLiteTable(
#    2434     name,
#    2435     self,
#    (...)
#    2440     dtype=dtype,
#    2441 )
#    2442 table.create()
# -> 2443 return table.insert(chunksize, method)
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2139, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    2137 def _execute_insert(self, conn, keys, data_iter) -> int:
#    2138     data_list = list(data_iter)
# -> 2139     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    2140     return conn.rowcount
#
# ProgrammingError: Error binding parameter 10: type 'dict' is not supported

# %%
lista_tabelas()
# Out:
#            name
# 0  restaurantes
# 1        bancos
# 2    corretoras
# 3       resties

# %%
resties_teste = carrega_bd('resties')

# %%
resties_teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             0 non-null      object
#  1   Tld              0 non-null      object
#  2   Cca2             0 non-null      object
#  3   Ccn3             0 non-null      object
#  4   Cca3             0 non-null      object
#  5   Independent      0 non-null      object
#  6   Status           0 non-null      object
#  7   Unmember         0 non-null      object
#  8   Currencies_Name  0 non-null      object
#  9   Idd              0 non-null      object
#  10  Capital          0 non-null      object
#  11  Altspellings     0 non-null      object
#  12  Region           0 non-null      object
#  13  Subregion        0 non-null      object
#  14  Languages        0 non-null      object
#  15  Translations     0 non-null      object
#  16  Latlng           0 non-null      object
#  17  Landlocked       0 non-null      object
#  18  Area             0 non-null      object
#  19  Demonyms         0 non-null      object
#  20  Flag             0 non-null      object
#  21  Maps             0 non-null      object
#  22  Population       0 non-null      object
#  23  Car              0 non-null      object
#  24  Timezones        0 non-null      object
#  25  Continents       0 non-null      object
#  26  Flags            0 non-null      object
#  27  Coatofarms       0 non-null      object
#  28  Startofweek      0 non-null      object
#  29  Capitalinfo      0 non-null      object
#  30  Borders          0 non-null      object
#  31  Cioc             0 non-null      object
#  32  Gini             0 non-null      object
#  33  Fifa             0 non-null      object
# dtypes: object(34)
# memory usage: 132.0+ bytes
